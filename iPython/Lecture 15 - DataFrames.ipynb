# %%
import numpy as np

import pandas as pd

from pandas import Series, DataFrame

# %%
# This is how to open a webbrowser from jupyter
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
# Copy and read data from the clipboard
nfl_frame = pd.read_clipboard()
# Variable = pd.read_clipboard()
# Out:
# /Users/randyhoang/anaconda3/lib/python3.6/site-packages/pandas/io/clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division
# 0          882   NFC East
# ...

# %%
# Returns the name of every single column

nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
nfl_frame.rank
# Out:
# <bound method NDFrame.rank of     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division
# ...

# %%
DataFrame(nfl_frame,columns=['Team','First NFL Season','Total Games'])
# Out:
#                        Team  First NFL Season Total Games
# 0            Dallas Cowboys              1960         882
# 1         Green Bay Packers              1921       1,336
# 2             Chicago Bears              1920       1,370
# 3            Miami Dolphins              1966         800
# 4   New England Patriots[b]              1960         884
# 5         Minnesota Vikings              1961         870
# 6          Baltimore Ravens              1996         352
# 7           New York Giants              1925       1,305
# 8            Denver Broncos              1960         884
# 9       San Francisco 49ers              1950       1,002
# 10      Pittsburgh Steelers              1933       1,172

# %%
DataFrame(nfl_frame,columns=['Team','First NFL Season','Total Games', 'Stadium'])
# Out:
#                        Team  First NFL Season Total Games  Stadium
# 0            Dallas Cowboys              1960         882      NaN
# 1         Green Bay Packers              1921       1,336      NaN
# 2             Chicago Bears              1920       1,370      NaN
# 3            Miami Dolphins              1966         800      NaN
# 4   New England Patriots[b]              1960         884      NaN
# 5         Minnesota Vikings              1961         870      NaN
# 6          Baltimore Ravens              1996         352      NaN
# 7           New York Giants              1925       1,305      NaN
# 8            Denver Broncos              1960         884      NaN
# 9       San Francisco 49ers              1950       1,002      NaN
# 10      Pittsburgh Steelers              1933       1,172      NaN

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division
# 0          882   NFC East
# ...

# %%
nfl_frame.head(3)
# See first 3 rows .head() will default give 5 rows
# Out:
#    Rank               Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys  502   374     6  0.573              1960
# 1     2  Green Bay Packers  737   562    37  0.565              1921
# 2     3      Chicago Bears  749   579    42  0.562              1920
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North

# %%
nfl_frame.tail(5)
# See last 5 rows with .tail()
# Out:
#     Rank                 Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 6      7     Baltimore Ravens  190   161     1  0.541              1996
# 7      8      New York Giants  687   585    33  0.539              1925
# 8      9       Denver Broncos  470   404    10  0.537              1960
# 9     10  San Francisco 49ers  528   460    14  0.534              1950
# 10    11  Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division
# 6          352  AFC North
# 7        1,305   NFC East
# 8          884   AFC West
# 9        1,002   NFC West
# 10       1,172  AFC North

# %%
nfl_frame.iloc[3]
# use .iloc to return all the information about the row
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Total Games                    800
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division         Stadium
# ...

# %%
nfl_frame['Stadium'] = np.arange(11)

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division  Stadium
# ...

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index = [4,0])
# Assign the index to stadiums 4 and 0

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums
#Input stadiums into the table

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division         Stadium
# ...

# %%
# Remove the column that we added 
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1           Dallas Cowboys  502   374     6  0.573              1960
# 1      2        Green Bay Packers  737   562    37  0.565              1921
# 2      3            Chicago Bears  749   579    42  0.562              1920
# 3      4           Miami Dolphins  445   351     4  0.559              1966
# 4      5  New England Patriots[b]  489   386     9  0.558              1960
# 5      6        Minnesota Vikings  470   390    10  0.546              1961
# 6      7         Baltimore Ravens  190   161     1  0.541              1996
# 7      8          New York Giants  687   585    33  0.539              1925
# 8      9           Denver Broncos  470   404    10  0.537              1960
# 9     10      San Francisco 49ers  528   460    14  0.534              1950
# 10    11      Pittsburgh Steelers  614   538    20  0.532              1933
#
#    Total Games   Division
# 0          882   NFC East
# ...

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
website = 'https://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
